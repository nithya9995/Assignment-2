# %%
#Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter("ignore")

# %%
# Now importing the data

# %%
df = pd.read_csv("nba_Player data.csv")

# %%
df.head(10)
# Out:
#                      Player Position  Age  Games  Minutes Played  \
# 0          Precious Achiuwa       PF   21     28           408.0
# 1              Jaylen Adams       PG   24      6            17.0
# 2              Steven Adams        C   27     27           760.0
# 3               Bam Adebayo        C   23     26           873.0
# 4         LaMarcus Aldridge        C   35     18           480.0
# 5         Ty-Shon Alexander       SG   22      3             8.0
# 6  Nickeil Alexander-Walker       SG   22     23           441.0
# 7             Grayson Allen       SG   25     19           454.0
# 8             Jarrett Allen        C   22     28           734.0
# 9             Jarrett Allen        C   22     12           320.0
#
#    True Shooting(%)  Threepoint Attempt rate  Free throw attempt rate  \
# 0             0.599                    0.000                    0.541
# 1             0.125                    0.250                    0.000
# ...

# %%
#preprossessing

# %%
df.describe()
# Out:
#               Age       Games  Minutes Played  True Shooting(%)  \
# count  497.000000  497.000000      495.000000        494.000000
# mean    25.623742   18.456740      416.492929          0.538939
# std      4.054229    8.311394      297.543620          0.130360
# min     19.000000    1.000000        2.000000          0.000000
# 25%     22.000000   12.000000      127.000000          0.500000
# 50%     25.000000   20.000000      417.000000          0.556000
# 75%     28.000000   26.000000      665.500000          0.607000
# max     37.000000   30.000000     1101.000000          1.500000
#
#        Threepoint Attempt rate  Free throw attempt rate  \
# count               495.000000               495.000000
# mean                  0.406362                 0.274804
# std                   0.234207                 0.270650
# min                   0.000000                 0.000000
# 25%                   0.255000                 0.142000
# ...

# %%
df.isnull().sum()
# Out:
# Player                      0
# Position                    0
# Age                         0
# Games                       0
# Minutes Played              2
# True Shooting(%)            3
# Threepoint Attempt rate     2
# Free throw attempt rate     2
# Player Efficiency Rating    0
# dtype: int64

# %%
df.fillna(value=0,inplace=True)

# %%
df.isnull().sum()
# Out:
# Player                      0
# Position                    0
# Age                         0
# Games                       0
# Minutes Played              0
# True Shooting(%)            0
# Threepoint Attempt rate     0
# Free throw attempt rate     0
# Player Efficiency Rating    0
# dtype: int64

# %%
#data visualization

# %%
sns.pairplot(df[["Games","Minutes Played","True Shooting(%)", "Threepoint Attempt rate", "Free throw attempt rate"]])

# %%
sns.pairplot(df)

# %%
sns.displot(df["Player Efficiency Rating"])

# %%
sns.distplot(df["Free throw attempt rate"])
# Out:
# <AxesSubplot:xlabel='Free throw attempt rate', ylabel='Density'>

# %%
sns.distplot(df["Threepoint Attempt rate"])
# Out:
# <AxesSubplot:xlabel='Threepoint Attempt rate', ylabel='Density'>

# %%
sns.distplot(df["True Shooting(%)"])
# Out:
# <AxesSubplot:xlabel='True Shooting(%)', ylabel='Density'>

# %%
##Finding the corelation of the output so to find the dependent and independent variable

# %%
df.corr()['Player Efficiency Rating']
# Out:
# Age                         0.164564
# Games                       0.379151
# Minutes Played              0.456036
# True Shooting(%)            0.679665
# Threepoint Attempt rate    -0.332640
# Free throw attempt rate     0.183740
# Player Efficiency Rating    1.000000
# Name: Player Efficiency Rating, dtype: float64

# %%
df.drop(labels=['Player', 'Position','Threepoint Attempt rate'], axis=1,inplace = True)

# %%
df.head()
# Out:
#    Age  Games  Minutes Played  True Shooting(%)  Free throw attempt rate  \
# 0   21     28           408.0             0.599                    0.541
# 1   24      6            17.0             0.125                    0.000
# 2   27     27           760.0             0.592                    0.397
# 3   23     26           873.0             0.641                    0.469
# 4   35     18           480.0             0.542                    0.093
#
#    Player Efficiency Rating
# 0                      15.1
# 1                      -6.9
# 2                      15.9
# 3                      22.7
# 4                      15.2

# %%
## 4. Assign dependent and independent variable

# %%
x = df.iloc[:,:-1].values

# %%
y = df.iloc[:,-1].values

# %%
x
# Out:
# array([[2.10e+01, 2.80e+01, 4.08e+02, 5.99e-01, 5.41e-01],
#        [2.40e+01, 6.00e+00, 1.70e+01, 1.25e-01, 0.00e+00],
#        [2.70e+01, 2.70e+01, 7.60e+02, 5.92e-01, 3.97e-01],
#        ...,
#        [2.20e+01, 2.60e+01, 9.01e+02, 5.98e-01, 5.77e-01],
#        [2.80e+01, 1.50e+01, 3.61e+02, 5.69e-01, 2.42e-01],
#        [2.30e+01, 3.00e+01, 5.86e+02, 7.22e-01, 5.00e-01]])

# %%
y
# Out:
# array([ 15.1,  -6.9,  15.9,  22.7,  15.2, -11.9,  12. ,  14. ,  22.5,
#         21.3,  23.5,   7.5,  17.8,  28.3,  -9.1,  10.3,  13.8,  10.3,
#         14.7,  11.2,  10.8,   8.9,  17.7,  10.6,  10.7,  13.9,  18.2,
#         14.2,  23.4,  12.6,  15.7,  13.1,  11.6,   0.3,  14.8,   8.4,
#         14.7,   9.6,  24.8,  16.7,   8. ,  13.2,  11.5,  13.7,  13. ,
#         14. ,  16.1,  18.3,  12.6,  12.6,  12.6,  -6. ,   9.9,  12.3,
#          4.7,  13.4,   9. ,   5. ,  17.2,  23.4,  17.8,  10.4,  20.3,
#         10.3,  11.4,  16.3,  12. ,  18.3,  10.3,  12.8,  22.3,  33.5,
#         12.9,   5.4,  16.4,  18.8,   8.9,  13.7,  13.5,  24.2,   9.2,
#         38.7,   9.8,  12.1,   2.1,  23.1,  29.8,   8.3,  17.1,   8.2,
#         11.5,  14.8,  10.7,  11.9,   5.3,  16.6,  19. ,  10.1,  19.3,
#         19.8,  13.2,  12.4,  15.1,  10. ,  11.6,  11.5,  10.7,  14.1,
#         25.6,  24.7,  12.2,  11.2,  21.7,  15.9,  18.6,  10.1,  12.7,
# ...

# %%
#5 . Divide the dataset into training set and testing set

# %%
from sklearn. model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split (x,y,test_size=0.3,random_state=7)

# %%
y_train.shape
# Out:
# (347,)

# %%
x_test.shape
# Out:
# (150, 5)

# %%
#6.Import Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
MLR=LinearRegression ()
MLR.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
MLR.coef_
# Out:
# array([-5.84792729e-02, -1.59486349e-01,  1.19308211e-02,  2.96912511e+01,
#         2.65249345e+00])

# %%
MLR.intercept_
# Out:
# -4.3211255226722365

# %%
y_pred=MLR.predict (x_test)
print (y_pred)
# Out:
# [14.72129916 11.23163098 22.02688969 12.49491303 -3.30989807  3.0914429
#  12.00488411 14.87595889 20.50252804 12.71469927 -6.06900227  1.26256711
#  12.99527632 12.69850313 10.64929041 12.4232556  14.71324297  6.43745199
#  14.50900155 14.69430594 20.28121211 11.845937   11.8930825   7.74122377
#  14.41387803 13.20271024  9.25625715  9.57450479 10.40406953  9.28567557
#  15.56705837 15.58390207  8.47673519 15.38332054 13.87886437 15.41826482
#  18.02131168 15.51078053 12.40258654 12.3681897  14.2404069  16.11320793
#   9.68284271 10.42297853 11.20089653  8.4345708  15.50859856  8.63141741
#  11.90184996 17.28314612 11.8806271   4.43075718 18.55898713 12.56155467
#  11.56172    15.78215777 20.15192697 14.80454071 15.98869539  9.24345646
#  13.47809141 13.5164887  12.25187755 10.75218962 -2.72208834  8.95488894
#  20.33768121 19.06203895 10.70393236 17.49251578 18.29651077 11.57472868
#  20.16935758 15.41814453 18.18030547 15.22682766  9.84924256 15.20495744
# ...

# %%
y_test
# Out:
# array([  9.3,  14.2,  31.4,  19.3,  -6. ,  -0.8,  12. ,  12. ,  28.3,
#         16. ,  -9.8,   0.3,  15.2,  13.3,   7.1,   9.7,  16.4,  11.6,
#          9.3,  17.3,  22.9,   9.6,  12.5,   0.9,  13. ,   8.2,   6.7,
#         12.4,  20.3,   3.2,  12.1,  13.8,   8.2,  16.7,  17.8,  12.4,
#         23.4,  12.4,  11.8,  12.2,  13.4,   9.5,  10.4,   7. ,  11.8,
#          8. ,   9.8,   7.6,  17.3,  14. ,  10.3,   0.5,  17.3,  16.7,
#         19.1,  14.7,  16.3,   5.6,  11.4,   9.2,  15.1,   8. ,  12.4,
#          6.4,  -9.7,   7.6,  15.7,  25.3,   8.1,  13.1,  17.5,   9.9,
#         23. ,  17.5,  19.9,  12.7,   9. ,  12.3,  15.9,  17.2,   9.8,
#         12.7,  10.8,  12.4,  16.4,   7.3,  11.5,  12.6,  10.1,   9.2,
#         20.4,  18.2,  17.2,   7.4,  11.3,  15.3,  17.3,   8.7,  12.6,
#         10.5,  18.9,  -9.1,  18.9,  24.7,  -5.9,  22.7,   9.8,  23.4,
#          8. ,   5.5,  18.6,  19.3,  10.7,   8. ,  13.2,  13.9,  13.1,
# ...

# %%
plt.plot (y_test, color="blue")
plt.plot (y_pred, color="red")

# %%
from sklearn.metrics import r2_score

r2_score(y_test,y_pred)
# Out:
# 0.6729840284529081
